# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 400)
pd.set_option('display.width', 1000)

songs = pd.read_csv('data/spotify_tracks.csv')
songs = songs.drop(["Unnamed: 0"], axis=1)
print(songs.info())
songs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693175 entries, 0 to 693174
# Data columns (total 19 columns):
# track_id             693175 non-null object
# track_popularity     693175 non-null int64
# artist_id            693175 non-null object
# artist_genres        693175 non-null object
# artist_popularity    693175 non-null float64
# artist_followers     693145 non-null float64
# acousticness         693175 non-null float64
# danceability         693175 non-null float64
# duration_ms          693175 non-null float64
# energy               693175 non-null float64
# instrumentalness     693175 non-null float64
# key                  693175 non-null float64
# liveness             693175 non-null float64
# loudness             693175 non-null float64
# mode                 693175 non-null float64
# speechiness          693175 non-null float64
# tempo                693175 non-null float64
# time_signature       693175 non-null float64
# ...

# %%
# Create Pop Songs DataFrame

# Create pop column of NaNs
songs['pop'] = np.nan

# Create boolean True if 'pop' is contained in artist_genres
songs['pop'] = songs.artist_genres.apply(lambda x: 'pop' in x)

# Create pop_songs dataframe
pop_songs = songs.loc[songs['pop'] == True]

# Re-set index
pop_songs.reset_index(inplace=True)

# Drop unnecessary columns
pop_songs = pop_songs.drop(['index', 'pop'], axis=1)

# Transform strings in 'artist_genres' column to lists
pop_songs['artist_genres'] = pop_songs.artist_genres.apply(lambda x: x.split(','))

# Copy dataframe to use later on
pop_songs2 = pop_songs.copy()

print(pop_songs.info())
pop_songs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162162 entries, 0 to 162161
# Data columns (total 19 columns):
# track_id             162162 non-null object
# track_popularity     162162 non-null int64
# artist_id            162162 non-null object
# artist_genres        162162 non-null object
# artist_popularity    162162 non-null float64
# artist_followers     162142 non-null float64
# acousticness         162162 non-null float64
# danceability         162162 non-null float64
# duration_ms          162162 non-null float64
# energy               162162 non-null float64
# instrumentalness     162162 non-null float64
# key                  162162 non-null float64
# liveness             162162 non-null float64
# loudness             162162 non-null float64
# mode                 162162 non-null float64
# speechiness          162162 non-null float64
# tempo                162162 non-null float64
# time_signature       162162 non-null float64
# ...

# %%
# Create list of unique genres

# Create array of lists from artist_genre column
genres_array = pop_songs.artist_genres.values

# Create a set of unique genres
unique_genres = set(x for l in genres_array for x in l)

# Convert set to list
unique_genres = list(unique_genres)

# Sort list of unique genres
unique_genres.sort()

# Count of unique subgenres
len(unique_genres)
# Out:
# 1962

# %%
# Create list of pop subgenres with for-loop
pop_subgenres = []
for genre in unique_genres:
    if "pop" in genre:
        pop_subgenres.append(genre)

len(pop_subgenres)
# Out:
# 322

# %%
# Creating new columns for each pop subgenre and assign NaN values
for genre in pop_subgenres:
    pop_songs[genre] = np.nan

# Assigning True Boolean value to pop subgenre columns 
for genre in pop_subgenres:
    pop_songs[genre] = pop_songs.artist_genres.apply(lambda x: genre in x)

# %%
# Create list of dictionaries with counts for each pop_subgenre
pop_subgenre_counts = []
for genre in pop_subgenres:
    info = {'pop_subgenre': genre, 'count': pop_songs[genre].sum()}
    pop_subgenre_counts.append(info)

# %%
# Create dataframe of pop_subgenres, and sort by count descending 
pop_subgenre_counts_df = pd.DataFrame(pop_subgenre_counts)
pop_subgenre_counts_df = pop_subgenre_counts_df.sort_values(by=['count'], ascending=False)
pop_subgenre_counts_df.head(20)
# Out:
#      count        pop_subgenre
# 229   6809                 pop
# 85    6166            dancepop
# 244   4878              poprap
# 120   4735             folkpop
# 108   3997          electropop
# 246   3861             poprock
# 149   3768      indiepoptimism
# 146   3647            indiepop
# 233   3573              popedm
# 39    3320          chamberpop
# 212   3315          newwavepop
# 181   3154            latinpop
# 249   3068         postteenpop
# 114   3017             europop
# 10    2982              artpop
# 175   2930                kpop
# 2     2796             afropop
# 242   2763             poppunk
# 254   2691  regionalmexicanpop
# 214   2650            noisepop

# %%
pop_songs2.head(100)
# Out:
#                   track_id  track_popularity               artist_id                                      artist_genres  artist_popularity  artist_followers  acousticness  danceability  duration_ms  energy  instrumentalness   key  liveness  loudness  mode  speechiness    tempo  time_signature  valence  dancepop  poprap  folkpop  electropop  poprock  indiepop  popedm  top_genre_count
# 0   000CfxgH11DeiTY9oCvZLJ                30  5ERkupmHea6uS0nwKr2zcz                                         [indiepop]               45.0           78607.0      0.094100         0.648     213693.0  0.2730          0.092400  11.0    0.0853    -4.897   1.0       0.0472  145.844             4.0   0.9040     False   False    False       False    False      True   False                1
# ...

# %%
# List of top 7
top_pop_subgenres = ['dancepop', 
                     'poprap', 
                     'folkpop', 
                     'electropop', 
                     'poprock', 
                     'indiepop', 
                     'popedm']

# %%
# Creating new columns for each pop subgenre and assign NaN values
for genre in top_pop_subgenres:
    pop_songs2[genre] = np.nan

# Assigning True Boolean value to pop subgenre columns 
for genre in top_pop_subgenres:
    pop_songs2[genre] = pop_songs2.artist_genres.apply(lambda x: genre in x)

# %%
pop_songs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162162 entries, 0 to 162161
# Data columns (total 27 columns):
# track_id             162162 non-null object
# track_popularity     162162 non-null int64
# artist_id            162162 non-null object
# artist_genres        162162 non-null object
# artist_popularity    162162 non-null float64
# artist_followers     162142 non-null float64
# acousticness         162162 non-null float64
# danceability         162162 non-null float64
# duration_ms          162162 non-null float64
# energy               162162 non-null float64
# instrumentalness     162162 non-null float64
# key                  162162 non-null float64
# liveness             162162 non-null float64
# loudness             162162 non-null float64
# mode                 162162 non-null float64
# speechiness          162162 non-null float64
# tempo                162162 non-null float64
# time_signature       162162 non-null float64
# ...

# %%
# Create new count column and fill with NaNs
pop_songs2['top_genre_count'] = np.nan

# %%
#Create column that counts number of subgenres per row that are True
pop_songs2['top_genre_count'] = pop_songs2.iloc[:,19:26].apply(lambda s: (s > 0).sum(), axis=1)

# %%
# See how many songs fit into 2+ subgenres
pop_songs2['top_genre_count'].value_counts()
# Out:
# 0    136766
# 1     20571
# 2      4239
# 3       536
# 4        50
# Name: top_genre_count, dtype: int64

# %%
# Take out songs with more than one subgenre
pop_songs2_filtered = pop_songs2[(pop_songs2['top_genre_count']<=1)]

# %%
# See how many songs fit into 2+ subgenres
pop_songs2_filtered.top_genre_count.value_counts()
# Out:
# 0    136766
# 1     20571
# Name: top_genre_count, dtype: int64

# %%
pop_songs2_filtered['target'] = 0
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in pop_songs2_filtered:
    
    if pop_songs2_filtered.top_genre_count[i] == 0:
        pop_songs2_filtered['target'][i] == 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-20a7ed43f06a> in <module>
#       1 for i in pop_songs2_filtered:
#       2
# ----> 3     if pop_songs2_filtered.top_genre_count[i] == 0:
#       4         pop_songs2_filtered['target'][i] == 0
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
# ...

# %%
pop_songs2_filtered.rows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-2dea03cc4f75> in <module>
# ----> 1 pop_songs2_filtered.rows()
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
songs5 = pop_songs2_filtered.drop(['artist_genres'], axis=1)

# %%
songs5.dancepop = songs5.dancepop.astype(int)
songs5.poprap = songs5.poprap.astype(int)
songs5.folkpop = songs5.folkpop.astype(int)
songs5.electropop = songs5.electropop.astype(int)
songs5.poprock = songs5.poprock.astype(int)
songs5.indiepop = songs5.indiepop.astype(int)
songs5.popedm = songs5.popedm.astype(int)

# %%
songs5.indiepop[0] = 1
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for index, row in songs5.iterrows():
    
    if songs5.top_genre_count[row] = 0:
        songs5['target'][row] = 0
    
    elif songs5.dancepop[row] = 1:
        songs5['target'][row] = 1
    
    elif songs5.poprap[row] = 1:
        songs5['target'][row] = 2
    
    elif songs5.folkpop[row] = 1:
        songs5['target'][row] = 3
    
    elif songs5.electropop[row] = 1:
        songs5['target'][row] = 4
    
    elif songs5.poprock[row] = 1:
        songs5['target'][row] = 5
    
    elif songs5.indiepop[row] = 1:
        songs5['target'][row] = 6
    
    elif songs5.popedm[row] = 1:
        songs5['target'][row] = 7
# Out:
#   File "<ipython-input-66-fd19bbdd5123>", line 3
#     if songs5.top_genre_count[row] = 0:
#                                    ^
# SyntaxError: invalid syntax
